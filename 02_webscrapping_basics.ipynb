# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the Wikipedia page you want to scrape
url = 'https://en.wikipedia.org/wiki/Web_scraping'


# Send an HTTP GET request to the URL
response = requests.get(url)

print(response)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract the page title
    title = soup.find('h1', id='firstHeading').text

    # Extract the first paragraph of the introduction
    intro_paragraph = soup.find('div', class_='mw-parser-output').p.text

    # Print the results
    print("Title:", title)
    print("Introduction:", intro_paragraph)
else:
    print("Failed to retrieve the Wikipedia page. Status code:", response.status_code)

print("---- Headings ----")
# find all headings 'h1', 'h2', 'h3', 'h4', 'h5', 'h6'
headings = soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6'])
for h in headings:
    print(h.text)



# lets scrape all the references!
ref_urls = soup.find_all('a', class_='external text')
for r in ref_urls:
    print(r)
    print(r["href"])
    print(r.text)
    print("-"*10)
# Out:
# <Response [200]>
# Title: Web scraping
# Introduction: Web scraping, web harvesting, or web data extraction is data scraping used for extracting data from websites.[1] Web scraping software may directly access the World Wide Web using the Hypertext Transfer Protocol or a web browser. While web scraping can be done manually by a software user, the term typically refers to automated processes implemented using a bot or web crawler. It is a form of copying in which specific data is gathered and copied from the web, typically into a central local database or spreadsheet, for later retrieval or analysis.
#
# ---- Headings ----
# Contents
# Web scraping
# History
# Techniques
# Human copy-and-paste
# Text pattern matching
# HTTP programming
# HTML parsing
# DOM parsing
# Vertical aggregation
# Semantic annotation recognizing
# Computer vision web-page analysis
# AI-powered document understanding
# Software
# Web Scraping Platforms
# Legal issues
# United States
# European Union
# Australia
# India
# Methods to prevent web scraping
# See also
# References
# <a class="external text" href="https://www.google.com/search?as_eq=wikipedia&amp;q=%22Web+scraping%22" rel="nofollow">"Web scraping"</a>
# https://www.google.com/search?as_eq=wikipedia&q=%22Web+scraping%22
# "Web scraping"
# ----------
# <a class="external text" href="https://www.google.com/search?tbm=nws&amp;q=%22Web+scraping%22+-wikipedia&amp;tbs=ar:1" rel="nofollow">news</a>
# https://www.google.com/search?tbm=nws&q=%22Web+scraping%22+-wikipedia&tbs=ar:1
# news
# ----------
# <a class="external text" href="https://www.google.com/search?&amp;q=%22Web+scraping%22&amp;tbs=bkt:s&amp;tbm=bks" rel="nofollow">newspapers</a>
# https://www.google.com/search?&q=%22Web+scraping%22&tbs=bkt:s&tbm=bks
# newspapers
# ----------
# <a class="external text" href="https://www.google.com/search?tbs=bks:1&amp;q=%22Web+scraping%22+-wikipedia" rel="nofollow">books</a>
# https://www.google.com/search?tbs=bks:1&q=%22Web+scraping%22+-wikipedia
# books
# ----------
# <a class="external text" href="https://scholar.google.com/scholar?q=%22Web+scraping%22" rel="nofollow">scholar</a>
# https://scholar.google.com/scholar?q=%22Web+scraping%22
# scholar
# ----------
# <a class="external text" href="https://www.jstor.org/action/doBasicSearch?Query=%22Web+scraping%22&amp;acc=on&amp;wc=on" rel="nofollow">JSTOR</a>
# https://www.jstor.org/action/doBasicSearch?Query=%22Web+scraping%22&acc=on&wc=on
# JSTOR
# ----------
# <a class="external text" href="https://en.wikipedia.org/w/index.php?title=Web_scraping&amp;action=edit">improve this section</a>
# https://en.wikipedia.org/w/index.php?title=Web_scraping&action=edit
# improve this section
# ----------
# <a class="external text" href="https://doi.org/10.5334%2Fdsj-2021-024" rel="nofollow">"SASSCAL WebSAPI: A Web Scraping Application Programming Interface to Support Access to SASSCAL's Weather Data"</a>
# https://doi.org/10.5334%2Fdsj-2021-024
# "SASSCAL WebSAPI: A Web Scraping Application Programming Interface to Support Access to SASSCAL's Weather Data"
# ----------
# <a class="external text" href="https://doi.org/10.5334%2Fdsj-2021-024" rel="nofollow">10.5334/dsj-2021-024</a>
# https://doi.org/10.5334%2Fdsj-2021-024
# 10.5334/dsj-2021-024
# ----------
# <a class="external text" href="https://search.worldcat.org/issn/1683-1470" rel="nofollow">1683-1470</a>
# https://search.worldcat.org/issn/1683-1470
# 1683-1470
# ----------
# <a class="external text" href="https://api.semanticscholar.org/CorpusID:237719804" rel="nofollow">237719804</a>
# https://api.semanticscholar.org/CorpusID:237719804
# 237719804
# ----------
# <a class="external text" href="http://www.searchenginehistory.com/" rel="nofollow">"Search Engine History.com"</a>
# http://www.searchenginehistory.com/
# "Search Engine History.com"
# ----------
# <a class="external text" href="https://web.archive.org/web/20161011080619/https://pdfs.semanticscholar.org/4fb4/3c5a212df751e84c3b2f8d29fabfe56c3616.pdf" rel="nofollow">"Joint optimization of wrapper generation and template detection"</a>
# https://web.archive.org/web/20161011080619/https://pdfs.semanticscholar.org/4fb4/3c5a212df751e84c3b2f8d29fabfe56c3616.pdf
# "Joint optimization of wrapper generation and template detection"
# ----------
# <a class="external text" href="https://doi.org/10.1145%2F1281192.1281287" rel="nofollow">10.1145/1281192.1281287</a>
# https://doi.org/10.1145%2F1281192.1281287
# 10.1145/1281192.1281287
# ----------
# <a class="external text" href="https://api.semanticscholar.org/CorpusID:833565" rel="nofollow">833565</a>
# https://api.semanticscholar.org/CorpusID:833565
# 833565
# ----------
# <a class="external text" href="https://pdfs.semanticscholar.org/4fb4/3c5a212df751e84c3b2f8d29fabfe56c3616.pdf" rel="nofollow">the original</a>
# https://pdfs.semanticscholar.org/4fb4/3c5a212df751e84c3b2f8d29fabfe56c3616.pdf
# the original
# ----------
# <a class="external text" href="http://www.gooseeker.com/en/node/knowledgebase/freeformat" rel="nofollow">Semantic annotation based web scraping</a>
# http://www.gooseeker.com/en/node/knowledgebase/freeformat
# Semantic annotation based web scraping
# ----------
# <a class="external text" href="http://www.xconomy.com/san-francisco/2012/07/25/diffbot-is-using-computer-vision-to-reinvent-the-semantic-web/" rel="nofollow">"Diffbot Is Using Computer Vision to Reinvent the Semantic Web"</a>
# http://www.xconomy.com/san-francisco/2012/07/25/diffbot-is-using-computer-vision-to-reinvent-the-semantic-web/
# "Diffbot Is Using Computer Vision to Reinvent the Semantic Web"
# ----------
# <a class="external text" href="https://doi.org/10.1016%2Fj.jbusres.2020.06.012" rel="nofollow">"TUTORIAL: AI research without coding: The art of fighting without fighting: Data science for qualitative researchers"</a>
# https://doi.org/10.1016%2Fj.jbusres.2020.06.012
# "TUTORIAL: AI research without coding: The art of fighting without fighting: Data science for qualitative researchers"
# ----------
# <a class="external text" href="https://doi.org/10.1016%2Fj.jbusres.2020.06.012" rel="nofollow">10.1016/j.jbusres.2020.06.012</a>
# https://doi.org/10.1016%2Fj.jbusres.2020.06.012
# 10.1016/j.jbusres.2020.06.012
# ----------
# <a class="external text" href="https://search.worldcat.org/issn/0148-2963" rel="nofollow">0148-2963</a>
# https://search.worldcat.org/issn/0148-2963
# 0148-2963
# ----------
# <a class="external text" href="https://web.archive.org/web/20020308222536/http://www.chillingeffects.org/linking/faq.cgi#QID596" rel="nofollow">"FAQ about linking – Are website terms of use binding contracts?"</a>
# https://web.archive.org/web/20020308222536/http://www.chillingeffects.org/linking/faq.cgi#QID596
# "FAQ about linking – Are website terms of use binding contracts?"
# ----------
# <a class="external text" href="http://www.chillingeffects.org/linking/faq.cgi#QID596" rel="nofollow">the original</a>
# http://www.chillingeffects.org/linking/faq.cgi#QID596
# the original
# ----------
# <a class="external text" href="http://scholarship.law.berkeley.edu/btlj/vol29/iss4/16/" rel="nofollow">"Symbiotic Relationships: Pragmatic Acceptance of Data Scraping"</a>
# http://scholarship.law.berkeley.edu/btlj/vol29/iss4/16/
# "Symbiotic Relationships: Pragmatic Acceptance of Data Scraping"
# ----------
# <a class="external text" href="https://doi.org/10.15779%2FZ38B39B" rel="nofollow">10.15779/Z38B39B</a>
# https://doi.org/10.15779%2FZ38B39B
# 10.15779/Z38B39B
# ----------
# <a class="external text" href="https://search.worldcat.org/issn/1086-3818" rel="nofollow">1086-3818</a>
# https://search.worldcat.org/issn/1086-3818
# 1086-3818
# ----------
# <a class="external text" href="http://www.tomwbell.com/NetLaw/Ch06.html" rel="nofollow">"Internet Law, Ch. 06: Trespass to Chattels"</a>
# http://www.tomwbell.com/NetLaw/Ch06.html
# "Internet Law, Ch. 06: Trespass to Chattels"
# ----------
# <a class="external text" href="https://web.archive.org/web/20020308222536/http://www.chillingeffects.org/linking/faq.cgi#QID460" rel="nofollow">"What are the "trespass to chattels" claims some companies or website owners have brought?"</a>
# https://web.archive.org/web/20020308222536/http://www.chillingeffects.org/linking/faq.cgi#QID460
# "What are the "trespass to chattels" claims some companies or website owners have brought?"
# ----------
# <a class="external text" href="http://www.chillingeffects.org/linking/faq.cgi#QID460" rel="nofollow">the original</a>
# http://www.chillingeffects.org/linking/faq.cgi#QID460
# the original
# ----------
# <a class="external text" href="http://www.tomwbell.com/NetLaw/Ch07/Ticketmaster.html" rel="nofollow">"Ticketmaster Corp. v. Tickets.com, Inc"</a>
# http://www.tomwbell.com/NetLaw/Ch07/Ticketmaster.html
# "Ticketmaster Corp. v. Tickets.com, Inc"
# ----------
# <a class="external text" href="https://web.archive.org/web/20110723131832/http://www.fornova.net/documents/AAFareChase.pdf" rel="nofollow">"American Airlines v. FareChase"</a>
# https://web.archive.org/web/20110723131832/http://www.fornova.net/documents/AAFareChase.pdf
# "American Airlines v. FareChase"
# ----------
# <a class="external text" href="http://www.fornova.net/documents/AAFareChase.pdf" rel="nofollow">the original</a>
# http://www.fornova.net/documents/AAFareChase.pdf
# the original
# ----------
# <a class="external text" href="https://web.archive.org/web/20160305025808/http://www.thefreelibrary.com/American+Airlines,+FareChase+Settle+Suit.-a0103213546" rel="nofollow">"American Airlines, FareChase Settle Suit"</a>
# https://web.archive.org/web/20160305025808/http://www.thefreelibrary.com/American+Airlines,+FareChase+Settle+Suit.-a0103213546
# "American Airlines, FareChase Settle Suit"
# ----------
# <a class="external text" href="http://www.thefreelibrary.com/American+Airlines,+FareChase+Settle+Suit.-a0103213546" rel="nofollow">the original</a>
# http://www.thefreelibrary.com/American+Airlines,+FareChase+Settle+Suit.-a0103213546
# the original
# ----------
# <a class="external text" href="http://www.imperva.com/docs/WP_Detecting_and_Blocking_Site_Scraping_Attacks.pdf" rel="nofollow">Detecting and Blocking Site Scraping Attacks</a>
# http://www.imperva.com/docs/WP_Detecting_and_Blocking_Site_Scraping_Attacks.pdf
# Detecting and Blocking Site Scraping Attacks
# ----------
# <a class="external text" href="https://web.archive.org/web/20110211123854/http://library.findlaw.com/2003/Jul/29/132944.html" rel="nofollow">"Controversy Surrounds 'Screen Scrapers': Software Helps Users Access Web Sites But Activity by Competitors Comes Under Scrutiny"</a>
# https://web.archive.org/web/20110211123854/http://library.findlaw.com/2003/Jul/29/132944.html
# "Controversy Surrounds 'Screen Scrapers': Software Helps Users Access Web Sites But Activity by Competitors Comes Under Scrutiny"
# ----------
# <a class="external text" href="http://library.findlaw.com/2003/Jul/29/132944.html" rel="nofollow">the original</a>
# http://library.findlaw.com/2003/Jul/29/132944.html
# the original
# ----------
# <a class="external text" href="https://web.archive.org/web/20130921054619/http://www.fornova.net/documents/Cvent.pdf" rel="nofollow">"QVC Inc. v. Resultly LLC, No. 14-06714 (E.D. Pa. filed Nov. 24, 2014)"</a>
# https://web.archive.org/web/20130921054619/http://www.fornova.net/documents/Cvent.pdf
# "QVC Inc. v. Resultly LLC, No. 14-06714 (E.D. Pa. filed Nov. 24, 2014)"
# ----------
# <a class="external text" href="http://www.fornova.net/documents/Cvent.pdf" rel="nofollow">the original</a>
# http://www.fornova.net/documents/Cvent.pdf
# the original
# ----------
# <a class="external text" href="https://www.scribd.com/doc/249068700/LinkedIn-v-Resultly-LLC-Complaint?secret_password=pEVKDbnvhQL52oKfdrmT" rel="nofollow">"QVC Inc. v. Resultly LLC, No. 14-06714 (E.D. Pa. filed Nov. 24, 2014)"</a>
# https://www.scribd.com/doc/249068700/LinkedIn-v-Resultly-LLC-Complaint?secret_password=pEVKDbnvhQL52oKfdrmT
# "QVC Inc. v. Resultly LLC, No. 14-06714 (E.D. Pa. filed Nov. 24, 2014)"
# ----------
# <a class="external text" href="http://newmedialaw.proskauer.com/2014/12/05/qvc-sues-shopping-app-for-web-scraping-that-allegedly-triggered-site-outage/" rel="nofollow">"QVC Sues Shopping App for Web Scraping That Allegedly Triggered Site Outage"</a>
# http://newmedialaw.proskauer.com/2014/12/05/qvc-sues-shopping-app-for-web-scraping-that-allegedly-triggered-site-outage/
# "QVC Sues Shopping App for Web Scraping That Allegedly Triggered Site Outage"
# ----------
# <a class="external text" href="https://web.archive.org/web/20110723132015/http://www.fornova.net/documents/pblog-bna-com.pdf" rel="nofollow">"Did Iqbal/Twombly Raise the Bar for Browsewrap Claims?"</a>
# https://web.archive.org/web/20110723132015/http://www.fornova.net/documents/pblog-bna-com.pdf
# "Did Iqbal/Twombly Raise the Bar for Browsewrap Claims?"
# ----------
# <a class="external text" href="http://www.fornova.net/documents/pblog-bna-com.pdf" rel="nofollow">the original</a>
# http://www.fornova.net/documents/pblog-bna-com.pdf
# the original
# ----------
# <a class="external text" href="https://www.techdirt.com/articles/20090605/2228205147.shtml" rel="nofollow">"Can Scraping Non-Infringing Content Become Copyright Infringement... Because Of How Scrapers Work? | Techdirt"</a>
# https://www.techdirt.com/articles/20090605/2228205147.shtml
# "Can Scraping Non-Infringing Content Become Copyright Infringement... Because Of How Scrapers Work? | Techdirt"
# ----------
# <a class="external text" href="https://www.eff.org/cases/facebook-v-power-ventures" rel="nofollow">"Facebook v. Power Ventures"</a>
# https://www.eff.org/cases/facebook-v-power-ventures
# "Facebook v. Power Ventures"
# ----------
# <a class="external text" href="https://www.reuters.com/technology/us-supreme-court-revives-linkedin-bid-shield-personal-data-2021-06-14/" rel="nofollow">"U.S. Supreme Court revives LinkedIn bid to shield personal data"</a>
# https://www.reuters.com/technology/us-supreme-court-revives-linkedin-bid-shield-personal-data-2021-06-14/
# "U.S. Supreme Court revives LinkedIn bid to shield personal data"
# ----------
# <a class="external text" href="https://techcrunch.com/2022/04/18/web-scraping-legal-court/" rel="nofollow">"Web scraping is legal, US appeals court reaffirms"</a>
# https://techcrunch.com/2022/04/18/web-scraping-legal-court/
# "Web scraping is legal, US appeals court reaffirms"
# ----------
# <a class="external text" href="https://web.archive.org/web/20071012005033/http://www.bvhd.dk/uploads/tx_mocarticles/S_-_og_Handelsrettens_afg_relse_i_Ofir-sagen.pdf" rel="nofollow">"UDSKRIFT AF SØ- &amp; HANDELSRETTENS DOMBOG"</a>
# https://web.archive.org/web/20071012005033/http://www.bvhd.dk/uploads/tx_mocarticles/S_-_og_Handelsrettens_afg_relse_i_Ofir-sagen.pdf
# "UDSKRIFT AF SØ- & HANDELSRETTENS DOMBOG"
# ----------
# <a class="external text" href="http://www.bvhd.dk/uploads/tx_mocarticles/S_-_og_Handelsrettens_afg_relse_i_Ofir-sagen.pdf" rel="nofollow">the original</a>
# http://www.bvhd.dk/uploads/tx_mocarticles/S_-_og_Handelsrettens_afg_relse_i_Ofir-sagen.pdf
# the original
# ----------
# <a class="external text" href="http://www.bailii.org/ie/cases/IEHC/2010/H47.html" rel="nofollow">"High Court of Ireland Decisions &gt;&gt; Ryanair Ltd -v- Billigfluege.de GMBH 2010 IEHC 47 (26 February 2010)"</a>
# http://www.bailii.org/ie/cases/IEHC/2010/H47.html
# "High Court of Ireland Decisions >> Ryanair Ltd -v- Billigfluege.de GMBH 2010 IEHC 47 (26 February 2010)"
# ----------
# <a class="external text" href="https://web.archive.org/web/20120624103316/http://www.lkshields.ie/htmdocs/publications/newsletters/update26/update26_03.htm" rel="nofollow">"Intellectual Property: Website Terms of Use"</a>
# https://web.archive.org/web/20120624103316/http://www.lkshields.ie/htmdocs/publications/newsletters/update26/update26_03.htm
# "Intellectual Property: Website Terms of Use"
# ----------
# <a class="external text" href="http://www.lkshields.ie/htmdocs/publications/newsletters/update26/update26_03.htm" rel="nofollow">the original</a>
# http://www.lkshields.ie/htmdocs/publications/newsletters/update26/update26_03.htm
# the original
# ----------
# <a class="external text" href="https://www.cnil.fr/fr/la-reutilisation-des-donnees-publiquement-accessibles-en-ligne-des-fins-de-demarchage-commercial" rel="nofollow">"La réutilisation des données publiquement accessibles en ligne à des fins de démarchage commercial | CNIL"</a>
# https://www.cnil.fr/fr/la-reutilisation-des-donnees-publiquement-accessibles-en-ligne-des-fins-de-demarchage-commercial
# "La réutilisation des données publiquement accessibles en ligne à des fins de démarchage commercial | CNIL"
# ----------
# <a class="external text" href="https://medium.com/@finddatalab/can-you-still-perform-web-scraping-with-the-new-cnil-guidelines-bf3e20d0edc2" rel="nofollow">"Can You Still Perform Web Scraping With The New CNIL Guidelines?"</a>
# https://medium.com/@finddatalab/can-you-still-perform-web-scraping-with-the-new-cnil-guidelines-bf3e20d0edc2
# "Can You Still Perform Web Scraping With The New CNIL Guidelines?"
# ----------
# <a class="external text" href="https://web.archive.org/web/20191203113701/https://www.lloyds.com/~/media/5880dae185914b2487bed7bd63b96286.ashx" rel="nofollow">"Spam Act 2003: An overview for business"</a>
# https://web.archive.org/web/20191203113701/https://www.lloyds.com/~/media/5880dae185914b2487bed7bd63b96286.ashx
# "Spam Act 2003: An overview for business"
# ----------
# <a class="external text" href="https://www.lloyds.com/~/media/5880dae185914b2487bed7bd63b96286.ashx" rel="nofollow">the original</a>
# https://www.lloyds.com/~/media/5880dae185914b2487bed7bd63b96286.ashx
# the original
# ----------
# <a class="external text" href="http://www.webstartdesign.com.au/spam_business_practical_guide.pdf" rel="nofollow">"Spam Act 2003: A practical guide for business"</a>
# http://www.webstartdesign.com.au/spam_business_practical_guide.pdf
# "Spam Act 2003: A practical guide for business"
# ----------
# <a class="external text" href="https://proxyway.com/guides/what-is-web-scraping" rel="nofollow">"Web Scraping for Beginners: A Guide 2024"</a>
# https://proxyway.com/guides/what-is-web-scraping
# "Web Scraping for Beginners: A Guide 2024"
# ----------
# <a class="external text" href="https://s3.us-west-2.amazonaws.com/research-papers-mynk/Breaking-Fraud-And-Bot-Detection-Solutions.pdf" rel="nofollow">Breaking Fraud &amp; Bot Detection Solutions</a>
# https://s3.us-west-2.amazonaws.com/research-papers-mynk/Breaking-Fraud-And-Bot-Detection-Solutions.pdf
# Breaking Fraud & Bot Detection Solutions
# ----------
# <a class="external text" href="https://wikimediafoundation.org/" rel="nofollow">Wikimedia Foundation, Inc.</a>
# https://wikimediafoundation.org/
# Wikimedia Foundation, Inc.
# ----------
